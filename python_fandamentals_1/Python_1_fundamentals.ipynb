# %% [markdown]
# # 1. Python Output

# %%
# Python is a case sensitive language
print('Hello World')
# Out:
# Hello World

# %%
print('hello world')
# Out:
# hello world

# %%
Print('hellow world')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1402435676.py in <cell line: 0>()
# ----> 1 Print('hellow world')
#
# NameError: name 'Print' is not defined

# %%
print('salman khan')
# Out:
# salman khan

# %%
print(salman khan)
# Out:
#   File "<ipython-input-3-0713073d8d88>", line 1
#     print(salman khan)
#                     ^
# SyntaxError: invalid syntax

# %%
print(anamul haque)
# Out:
#   File "/tmp/ipython-input-1429461331.py", line 1
#     print(anamul haque)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("anamul Haque")
# Out:
# anamul Haque

# %%
print(7)
# Out:
# 7

# %%
print(8)
# Out:
# 8

# %%
print(7.7)
# Out:
# 7.7

# %%
print(87.6)
# Out:
# 87.6

# %%
print(True)
# Out:
# True

# %%
print(false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4109613885.py in <cell line: 0>()
# ----> 1 print(false)
#
# NameError: name 'false' is not defined

# %%
print(False)
# Out:
# False

# %%
print('Hello',1,4.5,True)
# Out:
# Hello 1 4.5 True

# %%
print('hello',1,4,5,False)
# Out:
# hello 1 4 5 False

# %%
print('Hello',1,4.5,True,sep='/')
# Out:
# Hello/1/4.5/True

# %%
print('hello',1,4,5,True,sep='/')
# Out:
# hello/1/4/5/True

# %%
print('hello',1,4,5,True,sep='')
# Out:
# hello145True

# %%
print('hello',1,4,5,True,sep=',')
# Out:
# hello,1,4,5,True

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world

# %%
print('hello','world')
# Out:
# hello world

# %%
print('hello',end='  ')
print('world')
# Out:
# hello  world

# %%
print('hello',end=' ')
print('world')
# Out:
# hello world

# %%
print('hello',end='/')
print('world')
# Out:
# hello/world

# %%
print('hello',end='-','world')
# Out:
#   File "/tmp/ipython-input-3156739367.py", line 1
#     print('hello',end='-','world')
#                                  ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# # 2. Data Types

# %%
# Integer
print(8)
# 1*10^308
print(1e309)
# Out:
# 8
# inf

# %%
print(8)
# Out:
# 8

# %%
print(1e309)
# Out:
# inf

# %%
print(1e10)
# Out:
# 10000000000.0

# %%
# Decimal/Float
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
print(8.7)
# Out:
# 8.7

# %%
print(8.7e109)
# Out:
# 8.7e+109

# %%
print(1.7e309)
# Out:
# inf

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
print(False)
# Out:
# False

# %% [markdown]
# Bolean is not a text. so not in between inverted comma

# %%
print(True)
# Out:
# True

# %%
# Text/String
print('Hello World')
# Out:
# Hello World

# %%
print('heollllo worllld')
# Out:
# heollllo worllld

# %%
# complex
print(5+6j)
# Out:
# (5+6j)

# %%
print(5+6j)
# Out:
#   File "/tmp/ipython-input-15776616.py", line 1
#     print(5+6i)
#             ^
# SyntaxError: invalid decimal literal

# %%
print(5+6j)
# Out:
# (5+6j)

# %%
# List-> C-> Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
print([1,2,3,4,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary
print({'name':'Nitish','gender':'Male','weight':70})
# Out:
# {'name': 'Nitish', 'gender': 'Male', 'weight': 70}

# %%
print({'name':'Nitish','gender':'male','weight':70,'lang':'english'})
# Out:
# {'name': 'Nitish', 'gender': 'male', 'weight': 70, 'lang': 'english'}

# %%
# type
type([1,2,3])
# Out:
# list

# %%
type(2)
# Out:
# int

# %%
type({'x':'7'})
# Out:
# dict

# %%
type((1,2))
# Out:
# tuple

# %% [markdown]
# # 3. Variables == container

# %%
# Static Vs Dynamic Typing
# Static Vs Dynamic Binding
# stylish declaration techniques

# %%
# C/C++
name = 'nitish'
print(name)

a = 5
b = 6

print(a + b)
# Out:
# nitish
# 11

# %% [markdown]
# in python, don't need to declear the data type. It understand it automatically.

# %%
name='name'

# %%
print(name)
# Out:
# name

# %%
a=5
b=10
print(a)
print(b)
# Out:
# 5
# 10

# %%
print(a+b)
# Out:
# 15

# %% [markdown]
# in C/C++, need to declear the data dype
# int a=6

# %%
# Dynamic Typing
a = 5
# Static Typing
int a = 5

# %%
# Dynamic Binding
a = 5
print(a)
a = 'nitish'
print(a)

# Static Binding
int a = 5
# Out:
# 5
# nitish

# %% [markdown]
# no need to tell the data type in case of declering a variable= dynamic typing

# %% [markdown]
# dynamic binding= can be used same varibale for different data type for multiple time

# %%
a=10
print(a)
a='notish'
print(a)
# Out:
# 10
# notish

# %%
a=10
a='nitish'
print(a)
# Out:
# nitish

# %%
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=1
b=2
c=3
print(a,b,c)
# Out:
# 1 2 3

# %%
print(abc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2052855929.py in <cell line: 0>()
# ----> 1 print(abc)
#
# NameError: name 'abc' is not defined

# %%
print(a/b/c)
# Out:
# 0.16666666666666666

# %%
print(a,end='/',b,end='/',c)
# Out:
#   File "/tmp/ipython-input-429708234.py", line 1
#     print(a,end='/',b,end='/',c)
#                                ^
# SyntaxError: positional argument follows keyword argument

# %%
print(a,end='')
print(b,end='')
print(c)
# Out:
# 123

# %%
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
print(a, b, c)
# Out:
# 1 2 3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
print(a)
# Out:
# 1

# %%
print(b,c)
# Out:
# 2 3

# %%
a=b=c= 5
print(a,b,c)
# Out:
# 5 5 5

# %%
a,b,c=5
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1494191216.py in <cell line: 0>()
# ----> 1 a,b,c=5
#       2 print(a)
#
# TypeError: cannot unpack non-iterable int object

# %%
a,b,c=5
print(a,b,c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-478385153.py in <cell line: 0>()
# ----> 1 a,b,c=5
#       2 print(a,b,c)
#
# TypeError: cannot unpack non-iterable int object

# %%
a,b,c=5,5,5
print(a,b,c)
# Out:
# 5 5 5

# %%
a=b=c=5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # Comments

# %%
# this is a comment
# second line
a = 4
b = 6 # like this
# second comment
print(a+b)
# Out:
# 10

# %% [markdown]
# # 4. Keywords & Identifiers

# %% [markdown]
# to convert the human language to machine laanguage (1, 0) = compilation. In python, interoreter do this. Here some english word which stored for machine to understand the user motive are keywords.![image_2026-02-06_192020484.png](data:image/png;base64,...)

# %% [markdown]
# Do not use this key word as a variable. Because the interpreter will not understand

# %%
# Keywords

# %%
# Identifiers
# You can't start with a digit
name1 = 'Nitish'
print(name1)
# You can use special chars -> _
_ = 'ntiish'
print(_)
# identiers can not be keyword
# Out:
# Nitish
# ntiish

# %%
1arif='arif'
print(1arif)
# Out:
#   File "/tmp/ipython-input-3455955096.py", line 1
#     1arif='arif'
#     ^
# SyntaxError: invalid decimal literal

# %%
arif='arif'
print(arif)
# Out:
# arif

# %%
name1=arif
print(name1)
# Out:
# arif

# %%
name1='arif'
print(name1)
# Out:
# arif

# %%
name1-name2='arif'
print(nmae1-name2)
# Out:
#   File "/tmp/ipython-input-2228173479.py", line 1
#     name1-name2='arif'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
#only use under-score
name1_name2='arif'
print(name1_name2)
# Out:
# arif

# %%
#can only use under-score
_='arif'
print(_)
# Out:
# arif

# %%
name=print
print(name)
# Out:
# <built-in function print>

# %%
name='print'
print(name)
# Out:
# print

# %% [markdown]
# the variable name which we create are called identifier.

# %% [markdown]
# # Temp Heading

# %% [markdown]
# # 5. User Input

# %%
# Static Vs Dynamic
input('Enter Email')
# Out:
# Enter Emailnitish@gmail.com
# 'nitish@gmail.com'

# %%
input()
# Out:
# ioiio
# 'ioiio'

# %%
input()
# Out:
# 1232
# '1232'

# %%
input('enter your name: ')
# Out:
# enter your name: anamul haque arif
# 'anamul haque arif'

# %% [markdown]
# for take user input. Use input keyword.

# %%
# take input from users and store them in a variable
fnum = int(input('enter first number'))
snum = int(input('enter second number'))
#print(type(fnum),type(snum))
# add the 2 variables
result = fnum + snum
# print the result
print(result)
print(type(fnum))
# Out:
# enter first number56
# enter second number67
# 123
# <class 'int'>

# %%
#take two integer input from user. then add them and show
a=int(input('enter 1st int: '))
b=int(input('enrer 2nd int: '))
c=a+b
print(c)
type(c)
# Out:
# enter 1st int: 10
# enrer 2nd int: 20
# 30
# int

# %%
# if i don't declear the data type
a=input('enter the 1st value: ')
b=input('enter the 2nd value: ')
print(a,b)
type(a,b)
print(c=a+b)
# Out:
# enter the 1st value: 10
# enter the 2nd value: 20
# 10 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2015888718.py in <cell line: 0>()
#       3 b=input('enter the 2nd value: ')
#       4 print(a,b)
# ----> 5 type(a,b)
#       6 print(c=a+b)
#
# TypeError: type() takes 1 or 3 arguments

# %%
# if i don't declear the data type
a=input('enter the 1st value: ')
b=input('enter the 2nd value: ')
print(a,b)
type(a)
type(b)
print(c=a+b)
# Out:
# enter the 1st value: 10
# enter the 2nd value: 20
# 10 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2081742596.py in <cell line: 0>()
#       5 type(a)
#       6 type(b)
# ----> 7 print(c=a+b)
#
# TypeError: 'c' is an invalid keyword argument for print()

# %%
# if i don't declear the data type
a=input('enter the 1st value: ')
b=input('enter the 2nd value: ')
print(a,b)
type(a)
type(b)
c=a+b
print(c)
type(c)
# Out:
# enter the 1st value: 10
# enter the 2nd value: 20
# 10 20
# 1020
# str

# %%
a=input('enter the 1st number:')
print(a)
type(a)
# Out:
# enter the 1st number:10
# 10
# str

# %% [markdown]
# It means that the input type appear here is string automatically. So need to declear the input type inside it.

# %%
b=input('enter the 2nd number: ')
print(b)
type(b)
# Out:
# enter the 2nd number: 30
# 30
# str

# %%
c=a+b
print(c)
# Out:
# 1030

# %%
a=input('1st num: ')
b=input('2nd num: ')
c=a+b  #adding the both string
print(c)
type(a)
type(b)
# Out:
# 1st num: 10
# 2nd num: 20
# 1020
# str

# %%
#take user integer input
a=int(input('1st num: '))
b=int(int(input('2nd num: ')))
c=a+b
print(c)
type(c)
# Out:
# 1st num: 10
# 2nd num: 20
# 30
# int

# %%
print(a,b,sep=' ')
# Out:
# 10 20

# %%
print(a,end='-')
print(b)
# Out:
# 10-20

# %%
print(a,end=' ')
print(b)
# Out:
# 10 20

# %%
#take user integer input
a=int(input('1st num: '))
b=int((input('2nd num: ')))
c=a+b
print(c)
type(c)
# Out:
# 1st num: 10
# 2nd num: 20
# 30
# int

# %% [markdown]
# # 6. Type Conversion: conversion of data type

# %% [markdown]
# avoide the universal data type string data type problem

# %%
# Implicit Vs Explicit
print(5+5.6)
print(type(5),type(5.6))

print(4 + '4')
# Out:
# 10.6
# <class 'int'> <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-72e5c45cdb6f> in <module>
#       3 print(type(5),type(5.6))
#       4
# ----> 5 print(4 + '4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#implicit
print(5+5.6)
print(type(5),type(5.6))
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %% [markdown]
# programe automatically find out the type

# %%
print(4 +'4')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2658417670.py in <cell line: 0>()
# ----> 1 print(4 +'4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Explicit
# str -> int//convert string to integer
#int(4+5j)

# int to str
str(5)

# float
float(4)
# Out:
# 4.0

# %%
int('4')  #convert string to integer
type(int('4'))
# Out:
# int

# %%
int(4.5) # float to int
type(int(4.5))
# Out:
# int

# %%
int(4+5j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1226094765.py in <cell line: 0>()
# ----> 1 int(4+5j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
str(5)#int to str
# Out:
# '5'

# %%
float(5)# int to float
# Out:
# 5.0

# %%
a=input('enter 1st num:')#take str as a input
b=input('enter 2nd num: ')
c=int(a)+int(b)  #convert both a and b strt to int, then add
print(c)
print(type(c))
print(type(a))
print(type(b))
# Out:
# enter 1st num:10
# enter 2nd num: 20
# 30
# <class 'int'>
# <class 'str'>
# <class 'str'>

# %%
a=input('enter 1st num:')#take str as a input
b=input('enter 2nd num: ')
c=int(a)+int(b)  #convert both a and b strt to int, then add
print(c)
type(a)
type(b)
type(c)# for multiple type function, it show only the last one
# Out:
# enter 1st num:10
# enter 2nd num: 20
# 30
# int

# %%
a=input('enter 1st num:')#take str as a input
b=input('enter 2nd num: ')
c=int(a)+int(b)  #convert both a and b strt to int, then add
print(c)
type(c)
type(b)
type(a)# for multiple type function, it show only the last one
# Out:
# enter 1st num:20
# enter 2nd num: 30
# 50
# str

# %%
a=input('enter 1st num:')#take str as a input
b=input('enter 2nd num: ')
c=int(a)+int(b)  #convert both a and b strt to int, then add
print(c)
type(c)
type(a)
type(b)# for multiple type function, it show only the last one
# Out:
# enter 1st num:10
# enter 2nd num: 20
# 30
# str

# %% [markdown]
# # 7. Literals = the value which stored in the variables. Ex. a=2, here 2 is a lit

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal
c = 0o310 #Octal Literal of 200
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

#Complex Literal
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal
c = 0o310 #Octal Literal of 200
d = 0x12c #Hexadecimal Literal
print(a, b, c, d)
# Out:
# 10 100 200 300

# %%
x=3.14j
print(x)
# Out:
# 3.14j

# %%
x=1+3.14j
print(x,x.imag,x.real)
# Out:
# (1+3.14j) 3.14 1.0

# %%
# binary
x = 3.14j
print(x.imag)
# Out:
# 3.14

# %% [markdown]
# String will be represented between single or double or triple inverted comma.

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %%
a = True + 4 #in python True=1, false=0
b = False + 10

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %%
a=1+True
print(a)
# Out:
# 2

# %%
a=False+5
print(a)
# Out:
# 5

# %%
k = None
a = 5
b = 6
print('Program exe')
# Out:
# Program exe

# %%
k #wihtout any value, in python progammer can not declear any variable.
a = 5
b = 6
print('Program exe')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3307690790.py in <cell line: 0>()
# ----> 1 k #wihtout any value, in python progammer can not declear any variable.
#       2 a = 5
#       3 b = 6
#       4 print('Program exe')
#
# NameError: name 'k' is not defined

# %%
k = None # To neglect error and declear a variable for future use use 'None'
a = 5
b = 6
print('Program exe')
# Out:
# Program exe

# %% [markdown]
# # 8. Operators

# %%
# Arithmetic
# Relational
# Logical
# Bitwise
# Assignment
# Membership

# %% [markdown]
# # 9. If-Else
